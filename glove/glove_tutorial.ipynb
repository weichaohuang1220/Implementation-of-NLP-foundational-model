# %% [markdown]
# References:
#
# Jeffrey Pennington, Richard Socher, and Christopher Manning. 2014. [GloVe: Global Vectors for Word Representation.](https://aclanthology.org/D14-1162/) In Proceedings of the 2014 Conference on Empirical Methods in Natural Language Processing (EMNLP), pages 1532–1543, Doha, Qatar. Association for Computational Linguistics.
#
# https://www.bilibili.com/video/BV1Nt4y137iS/?spm_id_from=333.337.search-card.all.click&vd_source=c80bfceffe64af20ae2e48e4c0e27cd4

# %% [markdown]
# ### Abstract
# The glove mentioned a new computational method that compute ratio between center word anc context word.
# It turns out this method would aim to overcome flaw of global matrix factorization and local context window.
#
# ### Core:
# The semantic and syntactic linear structure observed in word vectir spaces based stem from ratio of word word occurance probablity.
#
#
# ### Examples
# A good cases in point are ice and solid  or steam and solid.
#
# There will be 4 situations, which are
# x =P(k|ice) and y=P(k|steam)
#
# For P = x/y
#
# ice close to solid more than steam= It depends
# steam close to gas more than ice = It depends
# Their  distances are very closed =1
# Their  distances are very hardly closed =1

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# How can I calculate P( k | i )?
#
# In corpus, it cotains three sentences below. X-axis is center words, and Y-axis is context word
#
# I like deep learning.
#
# I like NLP.
#
# I enjoy flying.

# %% [markdown]
# ![b61701d291ddbbf8086be677b091f316.jpg](data:image/jpeg;base64,...)
